# %% [markdown]
# # 🇮🇳 Exploring India: A Journey Through All States and Union Territories
#
# Welcome to an exciting journey across India! In this interactive notebook, you'll discover the incredible diversity of India through its **28 states** and **8 union territories**.
#
# ## What You'll Learn:
# - 📍 All states and their capitals
# - 🗣️ Languages and cultural diversity
# - 📊 Population and area comparisons
# - 🏛️ Famous landmarks and monuments
# - 🎭 Festivals and traditions
# - 🍛 Regional cuisines
#
# Let's start our adventure across this amazing country!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Create comprehensive data about Indian states and union territories
states_data = {
    'State/UT': [
        # States
        'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh',
        'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jharkhand',
        'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab',
        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
        'Uttar Pradesh', 'Uttarakhand', 'West Bengal',
        # Union Territories
        'Andaman and Nicobar Islands', 'Chandigarh', 'Dadra and Nagar Haveli and Daman and Diu',
        'Delhi', 'Jammu and Kashmir', 'Ladakh', 'Lakshadweep', 'Puducherry'
    ],
    'Capital': [
        # State capitals
        'Amaravati', 'Itanagar', 'Dispur', 'Patna', 'Raipur',
        'Panaji', 'Gandhinagar', 'Chandigarh', 'Shimla', 'Ranchi',
        'Bengaluru', 'Thiruvananthapuram', 'Bhopal', 'Mumbai', 'Imphal',
        'Shillong', 'Aizawl', 'Kohima', 'Bhubaneswar', 'Chandigarh',
        'Jaipur', 'Gangtok', 'Chennai', 'Hyderabad', 'Agartala',
        'Lucknow', 'Dehradun', 'Kolkata',
        # UT capitals
        'Port Blair', 'Chandigarh', 'Daman',
        'New Delhi', 'Srinagar (Summer), Jammu (Winter)', 'Leh', 'Kavaratti', 'Puducherry'
    ],
    'Type': [
        # States
        'State', 'State', 'State', 'State', 'State',
        'State', 'State', 'State', 'State', 'State',
        'State', 'State', 'State', 'State', 'State',
        'State', 'State', 'State', 'State', 'State',
        'State', 'State', 'State', 'State', 'State',
        'State', 'State', 'State',
        # Union Territories
        'UT', 'UT', 'UT', 'UT', 'UT', 'UT', 'UT', 'UT'
    ],
    'Region': [
        # States
        'South', 'Northeast', 'Northeast', 'East', 'Central',
        'West', 'West', 'North', 'North', 'East',
        'South', 'South', 'Central', 'West', 'Northeast',
        'Northeast', 'Northeast', 'Northeast', 'East', 'North',
        'West', 'Northeast', 'South', 'South', 'Northeast',
        'North', 'North', 'East',
        # Union Territories
        'South', 'North', 'West', 'North', 'North', 'North', 'South', 'South'
    ],
    'Population_Millions': [
        # States (approximate 2021 data)
        49.4, 1.4, 31.2, 104.1, 25.5,
        1.5, 60.4, 25.4, 6.9, 33.0,
        61.1, 33.4, 72.6, 112.4, 2.9,
        3.0, 1.1, 2.0, 42.0, 27.7,
        68.5, 0.6, 72.1, 35.0, 3.7,
        199.8, 10.1, 91.3,
        # Union Territories
        0.4, 1.1, 0.6, 16.8, 12.5, 0.3, 0.06, 1.2
    ],
    'Famous_For': [
        # States
        'Tirupati Temple, Spicy Food', 'Tawang Monastery, Tribal Culture', 'Tea Gardens, Kaziranga National Park',
        'Bodh Gaya, Ancient Universities', 'Tribal Culture, Forests', 'Beaches, Portuguese Heritage',
        'Rann of Kutch, Business Hub', 'Agriculture, Modern Cities', 'Hill Stations, Adventure Sports',
        'Tribal Culture, Minerals', 'IT Hub, Coffee, Mysore Palace', 'Backwaters, Spices, Ayurveda',
        'Khajuraho Temples, Tigers', 'Bollywood, Business Capital', 'Polo, Tribal Dances',
        'Living Root Bridges, Rainfall', 'Bamboo Dance, Hills', 'Hornbill Festival, Tribes',
        'Jagannath Temple, Classical Dance', 'Golden Temple, Agriculture', 'Deserts, Palaces, Forts',
        'Himalayas, Organic Farming', 'Temples, Classical Music', 'IT Hub, Biryani',
        'Tribal Culture, Bamboo', 'Taj Mahal, Ganges', 'Yoga, Char Dham', 'Durga Puja, Literature',
        # Union Territories
        'Islands, Marine Life', 'Planned City, Rock Garden', 'Beaches, Portuguese Forts',
        'Red Fort, India Gate', 'Dal Lake, Houseboats', 'Ladakh Monasteries, Mountains',
        'Coral Reefs, Coconuts', 'French Heritage, Beaches'
    ]
}

# Create DataFrame
india_df = pd.DataFrame(states_data)

print("🎉 Data loaded successfully!")
print(f"📊 Total States: {len(india_df[india_df['Type'] == 'State'])}")
print(f"🏛️ Total Union Territories: {len(india_df[india_df['Type'] == 'UT'])}")
print(f"🇮🇳 Total Population: {india_df['Population_Millions'].sum():.1f} million people")
print("\nLet's explore India together! 🚀")
# Out:
# 🎉 Data loaded successfully!
# 📊 Total States: 28
# 🏛️ Total Union Territories: 8
# 🇮🇳 Total Population: 1211.1 million people
#
# Let's explore India together! 🚀

# %% [markdown]
# ## 📊 Quick Overview: India at a Glance
#
# Let's start by looking at some basic facts about India's states and union territories!

# %%
# Display basic information
print("🗺️ INDIA'S ADMINISTRATIVE DIVISIONS")
print("=" * 40)

# Count by type
type_counts = india_df['Type'].value_counts()
print(f"States: {type_counts['State']}")
print(f"Union Territories: {type_counts['UT']}")
print(f"Total: {len(india_df)}")

print("\n🌍 REGIONAL DISTRIBUTION")
print("=" * 25)
region_counts = india_df['Region'].value_counts()
for region, count in region_counts.items():
    print(f"{region}: {count}")

# Create a simple visualization
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Pie chart for States vs UTs
colors1 = ['#FF6B6B', '#4ECDC4']
ax1.pie(type_counts.values, labels=type_counts.index, autopct='%1.1f%%', 
        colors=colors1, startangle=90)
ax1.set_title('States vs Union Territories', fontsize=14, fontweight='bold')

# Bar chart for regional distribution
colors2 = ['#FF6B6B', '#4ECDC4', '#45B7D1', '#96CEB4', '#FFEAA7']
bars = ax2.bar(region_counts.index, region_counts.values, color=colors2)
ax2.set_title('Distribution by Region', fontsize=14, fontweight='bold')
ax2.set_xlabel('Region')
ax2.set_ylabel('Number of States/UTs')
ax2.tick_params(axis='x', rotation=45)

# Add value labels on bars
for bar in bars:
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.1,
             f'{int(height)}', ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

print("\n💡 Did you know?")
print("India has more states than most countries have provinces!")
print("Each state has its own government and can make certain laws.")
# Out:
# 🗺️ INDIA'S ADMINISTRATIVE DIVISIONS
# ...
# States: 28
# Union Territories: 8
# Total: 36
#
# 🌍 REGIONAL DISTRIBUTION
# ...
# North: 9
# South: 8
# Northeast: 8
# West: 5
# East: 4
# Central: 2
# 💡 Did you know?
# India has more states than most countries have provinces!
# Each state has its own government and can make certain laws.

# %% [markdown]
# ## 👥 Population Powerhouses: Most and Least Populous States
#
# India is home to over 1.4 billion people! Let's see how they're distributed across different states.

# %%
# Sort states by population
states_only = india_df[india_df['Type'] == 'State'].copy()
states_sorted = states_only.sort_values('Population_Millions', ascending=False)

# Top 10 most populous states
top_10 = states_sorted.head(10)
bottom_5 = states_sorted.tail(5)

print("🏆 TOP 10 MOST POPULOUS STATES")
print("=" * 35)
for i, (_, row) in enumerate(top_10.iterrows(), 1):
    print(f"{i:2d}. {row['State/UT']:<20} - {row['Population_Millions']:>6.1f} million")

print("\n🌱 5 LEAST POPULOUS STATES")
print("=" * 30)
for i, (_, row) in enumerate(bottom_5.iterrows(), 1):
    print(f"{i}. {row['State/UT']:<20} - {row['Population_Millions']:>6.1f} million")

# Create visualization
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12))

# Top 10 states bar chart
bars1 = ax1.barh(range(len(top_10)), top_10['Population_Millions'], 
                 color=plt.cm.Reds(np.linspace(0.4, 0.8, len(top_10))))
ax1.set_yticks(range(len(top_10)))
ax1.set_yticklabels(top_10['State/UT'])
ax1.set_xlabel('Population (Millions)')
ax1.set_title('Top 10 Most Populous States', fontsize=14, fontweight='bold')
ax1.invert_yaxis()

# Add value labels
for i, bar in enumerate(bars1):
    width = bar.get_width()
    ax1.text(width + 1, bar.get_y() + bar.get_height()/2, 
             f'{width:.1f}M', ha='left', va='center', fontweight='bold')

# Bottom 5 states bar chart
bars2 = ax2.barh(range(len(bottom_5)), bottom_5['Population_Millions'], 
                 color=plt.cm.Blues(np.linspace(0.4, 0.8, len(bottom_5))))
ax2.set_yticks(range(len(bottom_5)))
ax2.set_yticklabels(bottom_5['State/UT'])
ax2.set_xlabel('Population (Millions)')
ax2.set_title('5 Least Populous States', fontsize=14, fontweight='bold')
ax2.invert_yaxis()

# Add value labels
for i, bar in enumerate(bars2):
    width = bar.get_width()
    ax2.text(width + 0.05, bar.get_y() + bar.get_height()/2, 
             f'{width:.1f}M', ha='left', va='center', fontweight='bold')

plt.tight_layout()
plt.show()

# Fun facts
largest_state = top_10.iloc[0]
smallest_state = bottom_5.iloc[-1]

print(f"\n🤯 Amazing Facts:")
print(f"• {largest_state['State/UT']} has {largest_state['Population_Millions']:.1f} million people!")
print(f"• That's {largest_state['Population_Millions']/smallest_state['Population_Millions']:.0f} times more than {smallest_state['State/UT']}!")
print(f"• If {largest_state['State/UT']} were a country, it would be the 5th most populous in the world!")
# Out:
# 🏆 TOP 10 MOST POPULOUS STATES
# ...
#  1. Uttar Pradesh        -  199.8 million
#  2. Maharashtra          -  112.4 million
#  3. Bihar                -  104.1 million
#  4. West Bengal          -   91.3 million
#  5. Madhya Pradesh       -   72.6 million
#  6. Tamil Nadu           -   72.1 million
#  7. Rajasthan            -   68.5 million
#  8. Karnataka            -   61.1 million
#  9. Gujarat              -   60.4 million
# 10. Andhra Pradesh       -   49.4 million
#
# 🌱 5 LEAST POPULOUS STATES
# ...
# 1. Nagaland             -    2.0 million
# 2. Goa                  -    1.5 million
# 3. Arunachal Pradesh    -    1.4 million
# 4. Mizoram              -    1.1 million
# 5. Sikkim               -    0.6 million
# 🤯 Amazing Facts:
# • Uttar Pradesh has 199.8 million people!
# • That's 333 times more than Sikkim!
# • If Uttar Pradesh were a country, it would be the 5th most populous in the world!

# %% [markdown]
# ## 🧠 Test Your Knowledge: India States Quiz!
#
# Let's see how much you've learned! Try to answer these questions about Indian states.

# %%
import random

# Quiz questions and answers
quiz_data = [
    {"question": "What is the capital of Karnataka?", "answer": "Bengaluru", "options": ["Bengaluru", "Chennai", "Hyderabad", "Mumbai"]},
    {"question": "Which state is famous for the Golden Temple?", "answer": "Punjab", "options": ["Punjab", "Haryana", "Rajasthan", "Gujarat"]},
    {"question": "What is the capital of Rajasthan?", "answer": "Jaipur", "options": ["Jaipur", "Jodhpur", "Udaipur", "Bikaner"]},
    {"question": "Which state is known as 'God's Own Country'?", "answer": "Kerala", "options": ["Kerala", "Goa", "Tamil Nadu", "Karnataka"]},
    {"question": "What is the most populous state in India?", "answer": "Uttar Pradesh", "options": ["Uttar Pradesh", "Maharashtra", "Bihar", "West Bengal"]}
]

print("🎯 INDIA STATES QUIZ")
print("=" * 20)
print("Let's test your knowledge about Indian states!\n")

# Select 3 random questions
selected_questions = random.sample(quiz_data, 3)

for i, q in enumerate(selected_questions, 1):
    print(f"Question {i}: {q['question']}")
    
    # Shuffle options
    options = q['options'].copy()
    random.shuffle(options)
    
    for j, option in enumerate(options, 1):
        print(f"  {j}. {option}")
    
    print(f"\n💡 Answer: {q['answer']}")
    print("-" * 40)

# Fun facts about states
print("\n🌟 AMAZING INDIA FACTS")
print("=" * 25)

fun_facts = [
    "🏔️ Ladakh is the largest union territory by area",
    "🌊 Lakshadweep is the smallest union territory", 
    "🎭 India has 22 official languages recognized by the Constitution",
    "🏛️ Chandigarh serves as the capital for both Punjab and Haryana",
    "🌴 Kerala has 100% literacy rate",
    "🐅 Madhya Pradesh has the most tiger reserves in India",
    "💎 Andhra Pradesh is famous for diamond mining",
    "🌧️ Meghalaya receives the highest rainfall in India"
]

for fact in random.sample(fun_facts, 5):
    print(fact)

print("\n🎉 Great job learning about India's states!")
print("Each state has its own unique story, culture, and traditions.")
# Out:
# 🎯 INDIA STATES QUIZ
# ...
# Let's test your knowledge about Indian states!
#
# Question 1: What is the most populous state in India?
#   1. Maharashtra
#   2. Bihar
#   3. West Bengal
#   4. Uttar Pradesh
#
# 💡 Answer: Uttar Pradesh
# ----------------------------------------
# Question 2: Which state is known as 'God's Own Country'?
#   1. Karnataka
#   2. Kerala
#   3. Goa
#   4. Tamil Nadu
#
# 💡 Answer: Kerala
# ----------------------------------------
# Question 3: What is the capital of Rajasthan?
#   1. Jodhpur
#   2. Udaipur
#   3. Jaipur
#   4. Bikaner
#
# 💡 Answer: Jaipur
# ----------------------------------------
#
# 🌟 AMAZING INDIA FACTS
# ...
# 🌊 Lakshadweep is the smallest union territory
# 🌴 Kerala has 100% literacy rate
# 🐅 Madhya Pradesh has the most tiger reserves in India
# 🎭 India has 22 official languages recognized by the Constitution
# 💎 Andhra Pradesh is famous for diamond mining
#
# 🎉 Great job learning about India's states!
# ...

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've just completed an amazing journey through India's states and union territories!
#
# ### 🌟 What You've Learned:
# - India has **28 states** and **8 union territories**
# - Each region has its own unique culture and traditions
# - Population varies greatly across different states
# - Every state contributes to India's incredible diversity
#
# ### 🚀 Next Steps:
# - Research more about your favorite state
# - Learn about the languages spoken in different regions
# - Explore the festivals and food of various states
# - Plan a virtual tour of India's famous landmarks
#
# ### 💡 Remember:
# India's strength lies in its diversity - "Unity in Diversity" is not just a motto, but a way of life!
#
# **Jai Hind! 🇮🇳**
